# %%
#Testing scraper for Twitchtracker
import urllib.request as urllib
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

import pandas as pd

#bypass 403 forbidden against web crawlers

#TODO:
#Write a loop that will iterate through all our data columns and pull the subscribers for those rows 
#
# test test test 
req = Request('https://twitchtracker.com/summit1g/subscribers', headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(req).read()

soup = BeautifulSoup(html)

table = soup.find(id="subscribers");
rows = table.find_all("tr");

df = pd.DataFrame(columns = ["Month"])

for row in rows:
    data = row.find_all("td");
    #Knowing the structure of the table, process all valid rows in standard order
    #Append each processed data item to our dataframe
    if len(data) != 0:
        month = data[0].get_text().strip()
        total = data[1].get_text().strip()
        prime = data[2].get_text().strip()
        Tier1 = data[3].get_text().strip()
        Tier2 = data[4].get_text().strip()
        Tier3 = data[5].get_text().strip()
        Unshared = data[6].get_text().strip()
        Gifted = data[7].get_text().strip()
        # Income calculate the total dollar amounts based on the subscriber payments of the Tiers 
        Income = (int(Tier1)*4.99) + (int(Tier2)*9.99) + (int(Tier3)*24.99)
#       If you want to see individual outputs
#         print("Date: " + month)
#         print("Viewers: " + viewers)
#         print("Channels: " + channels)
#         print("Time Watched: " + watched)
#         print("Streamers: " + streamers)
        data_dict = {"Month" : month, "Total": total, 
                     "Prime": prime, "Tier 1": Tier1, "Tier 2": Tier2, "Tier 3": Tier3, 
                     "Unshared": Unshared, "Gifted": Gifted, "Total Income": '${:,.2f}'.format(Income)}
        df = df.append(data_dict, ignore_index=True)
        
        
        
#Write our data and display the data
df.to_csv("channelsubdata.csv")
df
# Out:
#          Month Gifted  Prime Tier 1 Tier 2 Tier 3  Total Total Income Unshared
# 0   2016-09-01      0     26    707      0      0    895    $3,527.93      162
# 1   2016-10-01      0   5107   1247      0      0   7847    $6,222.53     1493
# 2   2016-11-01      0   3492   1290      0      0   5905    $6,437.10     1123
# 3   2016-12-01      0   5234   1446      0      0   8254    $7,215.54     1574
# 4   2017-01-01      0   5387   2117      0      0   9269   $10,563.83     1765
# 5   2017-02-01      0   4762   1515      0      0   7753    $7,559.85     1476
# 6   2017-03-01      0   6819   2000      0      0  10900    $9,980.00     2081
# 7   2017-04-01      0   6534   1841      0      0  10350    $9,186.59     1975
# 8   2017-05-01      0   6804   3435     29     67  12773   $19,104.69     2438
# 9   2017-06-01      0   9149   5686     60    107  18550   $31,646.47     3548
# 10  2017-07-01      0  11750   6266    108    114  22553   $35,195.12     4315
# 11  2017-08-01      0   9254   5519     98    101  18513   $31,042.82     3541
